# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("E-Commerce.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)

# %%
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %% [markdown]
# <font color = "black">
# <font size = 5>
#     First Method

# %%
print("The Number of rows in the dataset is:",ECom_Data.shape[0])
print("The Number of columns in the dataset is:",ECom_Data.shape[1])
# Out:
# The Number of rows in the dataset is: 8906
# The Number of columns in the dataset is: 17

# %% [markdown]
# <font color = "black">
# <font size = 5>
#     Second Method

# %%
print("The Number of rows in the dataset is:",len(ECom_Data.index))
print("The Number of rows in the dataset is:",len(ECom_Data.columns))
# Out:
# The Number of rows in the dataset is: 8906
# The Number of rows in the dataset is: 17

# %% [markdown]
# #### Ans  1 c)

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# <font color = "black">
# <font size = 5>
# The Number of Object datatype present in the data are 14. The summary gives the number of each datatype present in the dataset.

# %% [markdown]
# ### Ans 1 d)

# %% [markdown]
# <font color = "black">
# <font size = 5>
# There is no Boolean datatype in the dataset. The data types present in the data from the summary are float, int and object.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
ECom_Data.drop(["product_specifications","description"],axis=1,inplace=True)

# %% [markdown]
# ### Ans 2 b)

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# <font color = "black">
# <font size = 5>
# The function drop() is used to drop the rows/columns in the dataset. To remove the columns permanently inplace Parameter will be set as True. As the new summary clearly shows the columns - product_specifications and description are removed.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
print("The number of unique brand present in the dataset are:",ECom_Data["Brand"].nunique())
# Out:
# The number of unique brand present in the dataset are: 2484

# %% [markdown]
# ### Ans 3 b)

# %%
x = pd.pivot_table(ECom_Data,index="Brand",values="product_rating",aggfunc=np.mean)
x.rename(columns={"product_rating":"Average_product_rating"},inplace = True)
x
# Out:
#              Average_product_rating
# Brand
# 1OAK                       1.500000
# 3A AUTOCARE                3.268293
# 3D MAT                     3.000000
# 3KFACTORY                  2.000000
# 4D                         3.600000
# ...                             ...
# ZORDEN                     4.000000
# ZOSIGN                     3.400000
# ZRESTHA                    1.000000
# ZYXEL                      3.333333
#  TARKAN                    5.000000
#
# [2484 rows x 1 columns]

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %% [markdown]
# ### Ans 4 a)

# %%
plt.figure(figsize=(20,10))
sns.countplot(ECom_Data,x="product_main_category",order=list(ECom_Data["product_main_category"].value_counts(ascending=False).index))
plt.title("Product Category type",fontdict={"fontsize":20})
plt.xticks(label=list(ECom_Data["product_main_category"].value_counts(ascending=False).index),rotation=90,size=15)
plt.yticks(size=15)
plt.xlabel("Product category",fontsize=15)
plt.ylabel("Number of items ordered",fontsize=15)
plt.show()

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# <font color = "black">
# <font size = 5>
# From the graph we can interpret that the highest ordered product category is Clothing and the lowest ordered product category is wearable smart watches

# %% [markdown]
# ### Ans 4 c)

# %%
ECom_Data["product_main_category"].value_counts(ascending=False).head()
# Out:
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: product_main_category, dtype: int64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
for i in range(0,len(ECom_Data)):
    if(ECom_Data.loc[i,"discounted_price"]>600):
        ECom_Data.loc[i,"Revenue_Company"] = ECom_Data.loc[i,"discounted_price"]*0.25
    elif ((ECom_Data.loc[i,"discounted_price"]>350) & (ECom_Data.loc[i,"discounted_price"]<=600)):
        ECom_Data.loc[i,"Revenue_Company"] = ECom_Data.loc[i,"discounted_price"]*0.15
    elif ((ECom_Data.loc[i,"discounted_price"]>100) & (ECom_Data.loc[i,"discounted_price"]<=350)):
        ECom_Data.loc[i,"Revenue_Company"] = ECom_Data.loc[i,"discounted_price"]*0.10
    else:
        ECom_Data.loc[i,"Revenue_Company"] = ECom_Data.loc[i,"discounted_price"]*0.05

# %%
print("The Total Revenue of the E-Commerce Company from the commission is:",ECom_Data["Revenue_Company"].sum())
# Out:
# The Total Revenue of the E-Commerce Company from the commission is: 2217486.85

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
ECom_Data["BrandRevenue"] = ECom_Data["discounted_price"] - ECom_Data["Revenue_Company"]

# %%
print("The Total Brand Revenue is:",ECom_Data["BrandRevenue"].sum())
# Out:
# The Total Brand Revenue is: 7522992.15

# %%
y = pd.pivot_table(ECom_Data,index="Brand",values="BrandRevenue",aggfunc=np.sum)
y.sort_values(by="BrandRevenue",ascending=False).iloc[:10]
# Out:
#               BrandRevenue
# Brand
# ALLURE AUTO      498464.25
# GAGA             237390.00
# SLIM             212062.60
# DAILYOBJECTS     181980.00
# DIVINITI         143115.00
# THELOSTPUPPY     127287.50
# REGULAR          126536.50
# ENTHOPIA         123146.25
# ASUS              99241.50
# SPRINGWEL         88978.50

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
fig,axes = plt.subplots(figsize = (5,5))
sns.boxplot(ECom_Data,y="retail_price")
plt.title("Box Plot of Retail Price",fontdict={"fontsize":20})
axes.set_yscale("log");

# %%
fig,axes = plt.subplots(figsize = (5,5))
sns.boxplot(ECom_Data,y="discounted_price")
plt.title("Box Plot of Discounted Price",fontdict={"fontsize":20})
axes.set_yscale("log");

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# <font color = "black">
# <font size = 5>
# Yes. From the Boxplots of retail price and discounted price, we can infer that there are many outliers in the retail price and discounted price data.

# %% [markdown]
# ### Ans 7 c)

# %%
sns.scatterplot(ECom_Data,x="retail_price",y="discounted_price",color="Orange")
plt.title("Scatter Plot of Retail Price & Discounted Price");

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %%
z = pd.pivot_table(ECom_Data,index="Brand",values=["retail_price","discounted_price","BrandRevenue"],aggfunc={"retail_price":np.sum,"discounted_price":np.sum,"BrandRevenue":np.sum,"Brand":np.size})
z.rename(columns={"Brand":"Number_of_Orders"},inplace=True)
z.reset_index(inplace=True)
z
# Out:
#             Brand  Number_of_Orders  BrandRevenue  discounted_price  \
# 0            1OAK                 2       1015.40              1274
# 1     3A AUTOCARE                41      55647.90             74134
# 2          3D MAT                 1       5249.25              6999
# 3       3KFACTORY                 1        156.60               174
# 4              4D                 5       5961.00              7948
# ...           ...               ...           ...               ...
# 2479       ZORDEN                 1       2099.25              2799
# 2480       ZOSIGN                 5       5246.25              6995
# 2481      ZRESTHA                 1        674.25               899
# 2482        ZYXEL                 9      26544.00             35392
# 2483       TARKAN                 1        314.10               349
#
#       retail_price
# 0             1698
# 1           107059
# 2             7250
# 3              399
# 4            17500
# ...            ...
# ...

# %%
sns.pairplot(z[["Number_of_Orders","retail_price","discounted_price","BrandRevenue"]],diag_kind="kde");

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
ECom_Data["date"] = pd.to_datetime(ECom_Data["Order_Date"],dayfirst=True)
ECom_Data["year"] = ECom_Data["date"].dt.year
ECom_Data["month"] = ECom_Data["date"].dt.month
ECom_Data["day"] = ECom_Data["date"].dt.day
ECom_Data["year_month"] = ECom_Data["date"].dt.strftime('%Y/%m')

# %%
R = pd.pivot_table(ECom_Data,index=["Region","year_month"],values="Revenue_Company",aggfunc=np.sum).fillna(0)
R.reset_index(inplace=True)
R
# Out:
#    Region year_month  Revenue_Company
# 0   East     2020/12        363413.85
# 1   East     2021/01        218740.60
# 2   East     2021/02         14347.25
# 3   East     2021/03        124934.10
# 4   East     2021/04         56293.05
# ..    ...        ...              ...
# 32   West    2021/05         18631.85
# 33   West    2021/06         40579.80
# 34   West    2021/07           537.00
# 35   West    2021/08           736.75
# 36   West    2021/10           236.75
#
# [37 rows x 3 columns]

# %%
fig,axes = plt.subplots(figsize = (10,5))
sns.lineplot(R,x="year_month",y="Revenue_Company",hue="Region",style="Region",errorbar=None,estimator=np.sum);

# %%
fig,axes = plt.subplots(figsize = (10,5))
sns.lineplot(R[R["Region"] == "East "],x="year_month",y="Revenue_Company",errorbar=None,estimator=np.sum);

# %%
fig,axes = plt.subplots(figsize = (10,5))
sns.lineplot(R[R["Region"] == "West"],x="year_month",y="Revenue_Company",errorbar=None,estimator=np.sum);

# %%
fig,axes = plt.subplots(figsize = (10,5))
sns.lineplot(R[R["Region"] == "North"],x="year_month",y="Revenue_Company",errorbar=None,estimator=np.sum);

# %%
fig,axes = plt.subplots(figsize = (10,5))
sns.lineplot(R[R["Region"] == "South"],x="year_month",y="Revenue_Company",errorbar=None,estimator=np.sum);

# %% [markdown]
# ### Ans 9 b)

# %%
pd.pivot_table(ECom_Data,index="Region",columns="year_month",values="Revenue_Company",aggfunc=np.sum).fillna(0)
# Out:
# year_month    2020/12    2021/01   2021/02    2021/03   2021/04   2021/05  \
# Region
# East        363413.85  218740.60  14347.25  124934.10  56293.05  24230.50
# North       195149.95   96015.10   7137.35   40733.95  29758.35  13106.50
# South        95088.25   52815.80   4670.85   61932.15  18550.10   3708.75
# West        302971.95  145593.75  15020.90  119632.50  46845.20  18631.85
#
# year_month   2021/06  2021/07  2021/08  2021/09  2021/10
# Region
# East        54231.60   351.35   824.75   680.15   202.25
# North       29552.35   306.00   374.75     0.00     0.00
# South       19550.75     0.00     0.00     0.00     0.00
# West        40579.80   537.00   736.75     0.00   236.75

# %% [markdown]
# <font color = "black">
# <font size = 5>
# From the Above graphs and pivot table we can clearly see that the dataset range from December 2020 to October 2021.
# For all the region Best performing month is December. The Worst performing month is July, August, September and October. The Inference is based only on the period of range given in the dataset.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
